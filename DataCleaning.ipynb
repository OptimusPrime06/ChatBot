# %% [markdown]
# ## Import data

# %% [markdown]
# ### Custom dataset

# %%
import pandas as pd

customDf = pd.read_csv('dataset.csv')
print(customDf.iloc[1:21])
# Out:
#                                 Statement    Intent DrowsinessLevel  RepFlag
# 1                              I'm tired.    answer            high        0
# 2                        What time is it?  question             low        0
# 3                           I don't know.    answer            high        0
# 4                Can you ask me a puzzle?  question             low        0
# 5   Sure, what has an eye but cannot see?    puzzle          medium        0
# 6                               A needle.    answer          medium        0
# 7           What's the capital of France?  question             low        0
# 8                                  Paris.    answer             low        0
# 9                 Can you sing me a song?  question             low        0
# 10       Twinkle, twinkle, little star...    answer             low        0
# 11                    I'm feeling sleepy.    answer            high        0
# ...

# %%
print(customDf.iloc[21:41])
# Out:
#                                 Statement    Intent DrowsinessLevel  RepFlag
# 21                      I'm feeling lost.    answer            high        0
# 22               I don't know where I am.    answer            high        0
# 23              Can you help me navigate?  question            high        0
# 24                   I'm feeling anxious.    answer            high        0
# 25                  Can you calm me down?  question            high        0
# 26       What's the weather like outside?  question             low        0
# 27                          It's raining.    answer             low        0
# 28   What's the speed limit on this road?  question             low        0
# 29                          I don't know.    answer            high        0
# 30     Can you remind me to take my exit?  question             low        0
# 31                 Sure, I'll remind you.    answer             low        0
# ...

# %%
print(customDf.iloc[41:60])
# Out:
#                                             Statement    Intent  \
# 41                                           A shirt.    answer
# 42                           Can you ask me a puzzle?  question
# 43  I have cities, but no houses; I have mountains...    puzzle
# 44                                             A map.    answer
# 45                           Can you ask me a puzzle?  question
# 46  What runs but never walks, has a mouth but nev...    puzzle
# 47                                           A river.    answer
# 48                           Can you ask me a puzzle?  question
# 49                    What has an eye but cannot see?    puzzle
# 50                                          A needle.    answer
# 51                           Can you ask me a puzzle?  question
# 52                      What has leaves but no roots?    puzzle
# 53                                            A book.    answer
# 54                           Can you ask me a puzzle?  question
# ...

# %%
print(customDf.iloc[61:80])
# Out:
#                                             Statement     Intent  \
# 61                  What has a face but cannot smile?     puzzle
# 62                                           A clock.     answer
# 63       I am often given, but never kept. What am I?     puzzle
# 64                                          A promise     answer
# 65  I have no voice, but I can tell you many stori...     puzzle
# 66                                             A book     answer
# 67  I have no legs, but I can travel the world. Wh...     puzzle
# 68                                             A book     answer
# 69  I am always coming, but also always going. Wha...     puzzle
# 70                                               Time     answer
# 71  I am often full of dreams, but have no sleep. ...     puzzle
# 72                                             A book     answer
# 73                       What’s the capital of Japan?   question
# ...

# %%
print(customDf.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Statement        80 non-null     object
#  1   Intent           80 non-null     object
#  2   DrowsinessLevel  80 non-null     object
#  3   RepFlag          80 non-null     int64
# dtypes: int64(1), object(3)
# memory usage: 2.6+ KB
# None

# %% [markdown]
# ### Riddle dataset

# %%
rdf = pd.read_csv('Riddles.csv')
rdf
# Out:
#                                                 Riddle      Answer  \
# 0    I speak without a mouth and hear without ears....     An echo
# 1    The more you take, the more you leave behind. ...   Footsteps
# 2    I have cities, but no houses. I have mountains...       A map
# 3    What has keys, but no locks; space, but no roo...  A keyboard
# 4    I'm tall when I'm young, and I'm short when I'...    A candle
# ..                                                 ...         ...
# 995         What kind of room has no doors or windows?  A mushroom
# 996       What has to be broken before you can use it?      An egg
# 997  What travels around the world but stays in the...     A stamp
# 998  What is always in front of you but can’t be seen?  The future
# 999             What gets sharper the more you use it?  Your brain
#
#                                                   Hint
# 0    Think about a sound that repeats itself in nature
# ...

# %%
print(rdf.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Riddle  1000 non-null   object
#  1   Answer  1000 non-null   object
#  2   Hint    1000 non-null   object
# dtypes: object(3)
# memory usage: 23.6+ KB
# None

# %% [markdown]
# ### Conversation dataset

# %%
cdf = pd.read_csv('Conversation.csv')
cdf
# Out:
#       Unnamed: 0                                           question  \
# 0              0                             hi, how are you doing?
# 1              1                      i'm fine. how about yourself?
# 2              2                i'm pretty good. thanks for asking.
# 3              3                  no problem. so how have you been?
# 4              4                   i've been great. what about you?
# ...          ...                                                ...
# 3720        3720    that's a good question. maybe it's not old age.
# 3721        3721                              are you right-handed?
# 3722        3722                                  yes. all my life.
# 3723        3723  you're wearing out your right hand. stop using...
# 3724        3724        but i do all my writing with my right hand.
#
#                                                  answer
# 0                         i'm fine. how about yourself?
# ...

# %%
print(cdf.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3725 entries, 0 to 3724
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  3725 non-null   int64
#  1   question    3725 non-null   object
#  2   answer      3725 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 87.4+ KB
# None

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Riddles dataset cleaning

# %%
cleanRdf= rdf.drop(columns='Hint')
cleanRdf
# Out:
#                                                 Riddle      Answer
# 0    I speak without a mouth and hear without ears....     An echo
# 1    The more you take, the more you leave behind. ...   Footsteps
# 2    I have cities, but no houses. I have mountains...       A map
# 3    What has keys, but no locks; space, but no roo...  A keyboard
# 4    I'm tall when I'm young, and I'm short when I'...    A candle
# ..                                                 ...         ...
# 995         What kind of room has no doors or windows?  A mushroom
# 996       What has to be broken before you can use it?      An egg
# 997  What travels around the world but stays in the...     A stamp
# 998  What is always in front of you but can’t be seen?  The future
# 999             What gets sharper the more you use it?  Your brain
#
# [1000 rows x 2 columns]

# %% [markdown]
# ### Clean Conversation dataset

# %%
cleanCdf = cdf.drop(columns=[col for col in cdf.columns if col.startswith('Unnamed')])
cleanCdf
# Out:
#                                                question  \
# 0                                hi, how are you doing?
# 1                         i'm fine. how about yourself?
# 2                   i'm pretty good. thanks for asking.
# 3                     no problem. so how have you been?
# 4                      i've been great. what about you?
# ...                                                 ...
# 3720    that's a good question. maybe it's not old age.
# 3721                              are you right-handed?
# 3722                                  yes. all my life.
# 3723  you're wearing out your right hand. stop using...
# 3724        but i do all my writing with my right hand.
#
#                                                  answer
# 0                         i'm fine. how about yourself?
# 1                   i'm pretty good. thanks for asking.
# 2                     no problem. so how have you been?
# 3                      i've been great. what about you?
# ...

# %% [markdown]
# ### Adding riddles to our custom dataset

# %%
# Iterate over the range of indices
for i, puzzle in enumerate(cleanRdf['Riddle']):
    # Calculate the target index in customDf
    target_index = customDf.index.max()+1
    # Assign the riddle to the Statement column in customDf
    customDf.loc[target_index, 'Statement'] = puzzle
    customDf.loc[target_index, 'Intent'] = 'puzzle'
    customDf.loc[target_index, 'DrowsinessLevel'] = 'low'
    customDf.loc[target_index, 'RepFlag'] = 0



for i, answers in enumerate(cleanRdf['Answer']):
    # Calculate the target index in customDf
    target_index = customDf.index.max()+1
    # Assign the riddle to the Statement column in customDf
    customDf.loc[target_index, 'Statement'] = answers
    customDf.loc[target_index, 'DrowsinessLevel'] = 'low'
    customDf.loc[target_index, 'Intent'] = 'answer'
    customDf.loc[target_index, 'RepFlag'] = 0



print(customDf.loc[81:100])
# Out:
#                                              Statement  Intent  \
# 81   The more you take, the more you leave behind. ...  puzzle
# 82   I have cities, but no houses. I have mountains...  puzzle
# 83   What has keys, but no locks; space, but no roo...  puzzle
# 84   I'm tall when I'm young, and I'm short when I'...  puzzle
# 85   What has a head and a tail that are only made ...  puzzle
# 86   I have branches, but no fruit, trunk or leaves...  puzzle
# 87   What is always in front of you but can't be seen?  puzzle
# 88   I have a head and a tail that will never meet....  puzzle
# 89      What gets wetter and wetter the more it dries?  puzzle
# 90   I'm light as a feather, yet the strongest pers...  puzzle
# 91   I'm not alive, but I grow; I don't have lungs,...  puzzle
# 92   I have keys, but no locks. I have space, but n...  puzzle
# 93   What comes once in a minute, twice in a moment...  puzzle
# 94   I am taken from a mine and shut up in a wooden...  puzzle
# ...

# %%
print(customDf.loc[1700:1710])
# Out:
#                Statement  Intent DrowsinessLevel  RepFlag
# 1700          A building  answer             low      0.0
# 1701                Fire  answer             low      0.0
# 1702           A problem  answer             low      0.0
# 1703  A computer program  answer             low      0.0
# 1704        A flower bed  answer             low      0.0
# 1705       Body language  answer             low      0.0
# 1706           A science  answer             low      0.0
# 1707             A fever  answer             low      0.0
# 1708             A chart  answer             low      0.0
# 1709              Volume  answer             low      0.0
# 1710               A pin  answer             low      0.0

# %% [markdown]
# ### Adding conversations to our custom dataset

# %%
# Iterate over the range of indices
for i, questions in enumerate(cleanCdf['question']):
    # Calculate the target index in customDf
    target_index = customDf.index.max()+1
    # Assign the riddle to the Statement column in customDf
    customDf.loc[target_index, 'Statement'] = questions
    if questions.strip().endswith('?'):
        customDf.loc[target_index, 'Intent'] = 'question'
    else:
        customDf.loc[target_index, 'Intent'] = 'answer'
    customDf.loc[target_index, 'DrowsinessLevel'] = 'medium'
    customDf.loc[target_index, 'Intent'] = 'answer'
    customDf.loc[target_index, 'RepFlag'] = 0

for i, answers in enumerate(cleanCdf['answer']):
    # Calculate the target index in customDf
    target_index = customDf.index.max()+1
    # Assign the riddle to the Statement column in customDf
    customDf.loc[target_index, 'Statement'] = answers
    if answers.strip().endswith('?'):
        customDf.loc[target_index, 'Intent'] = 'question'
    else:
        customDf.loc[target_index, 'Intent'] = 'answer'
    customDf.loc[target_index, 'DrowsinessLevel'] = 'medium'
    customDf.loc[target_index, 'Intent'] = 'answer'
    customDf.loc[target_index, 'RepFlag'] = 0

print(customDf.loc[9100:9110])
# Out:
#                                               Statement  Intent  \
# 9100      that's perfect. the less traffic, the better.  answer
# 9101                                           me, too.  answer
# 9102  we have a 2 o'clock appointment to see the one...  answer
# 9103                       we'd better get ready to go.  answer
# 9104                             it's an upstairs unit.  answer
# 9105  that's good, because i don't want to live unde...  answer
# 9106                            and it's a corner unit.  answer
# 9107  that's great. we won't have neighbors on both ...  answer
# 9108                               no pets are allowed.  answer
# 9109  perfect. we don't have to listen to barking dogs.  answer
# 9110  and there are only six units in the whole buil...  answer
#
#      DrowsinessLevel  RepFlag
# 9100          medium      0.0
# 9101          medium      0.0
# 9102          medium      0.0
# 9103          medium      0.0
# 9104          medium      0.0
# ...

# %%
customDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9530 entries, 0 to 9529
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Statement        9530 non-null   object
#  1   Intent           9530 non-null   object
#  2   DrowsinessLevel  9530 non-null   object
#  3   RepFlag          9530 non-null   float64
# dtypes: float64(1), object(3)
# memory usage: 297.9+ KB
